# %%
import polars as pl
from nltk import word_tokenize
import numpy as np

# %%
df = pl.read_csv('train.csv')
df.head()
# Out:
# shape: (5, 3)
# ┌─────────┬─────────────────────────────────────┬────────┐
# │ id      ┆ text                                ┆ author │
# │ ---     ┆ ---                                 ┆ ---    │
# │ str     ┆ str                                 ┆ str    │
# ╞═════════╪═════════════════════════════════════╪════════╡
# │ id26305 ┆ This process, however, afforded ... ┆ EAP    │
# │ id17569 ┆ It never once occurred to me tha... ┆ HPL    │
# │ id11008 ┆ In his left hand was a gold snuf... ┆ EAP    │
# │ id27763 ┆ How lovely is spring As we looke... ┆ MWS    │
# │ id12958 ┆ Finding nothing else, not even g... ┆ HPL    │
# └─────────┴─────────────────────────────────────┴────────┘

# %%
k = 10
alpha =  min(0.1,50/k)
beta = 0.01

# %%
W = df.with_columns([
    pl.col('text').apply(lambda x: word_tokenize(x.lower())).alias('words')
]).explode('words').select([
    pl.col('id').alias('doc_id'),
    pl.col('words').alias('token'),
    pl.col('author')
])
W = W.with_columns([pl.Series(name='topic', values=np.random.choice(np.arange(10), len(W),  p=[1/k]*k))])
W
# Out:
# shape: (594922, 4)
# ┌─────────┬─────────┬────────┬───────┐
# │ doc_id  ┆ token   ┆ author ┆ topic │
# │ ---     ┆ ---     ┆ ---    ┆ ---   │
# │ str     ┆ str     ┆ str    ┆ i32   │
# ╞═════════╪═════════╪════════╪═══════╡
# │ id26305 ┆ this    ┆ EAP    ┆ 4     │
# │ id26305 ┆ process ┆ EAP    ┆ 8     │
# │ id26305 ┆ ,       ┆ EAP    ┆ 4     │
# │ id26305 ┆ however ┆ EAP    ┆ 5     │
# │ ...     ┆ ...     ┆ ...    ┆ ...   │
# │ id00393 ┆ that    ┆ HPL    ┆ 9     │
# │ id00393 ┆ of      ┆ HPL    ┆ 1     │
# │ id00393 ┆ mirth   ┆ HPL    ┆ 5     │
# │ id00393 ┆ .       ┆ HPL    ┆ 8     │
# └─────────┴─────────┴────────┴───────┘

# %%
V = W.groupby(['token', 'topic']).count().with_columns([
    pl.col('topic').apply(lambda x: f'k{x}')
]).pivot(values='count', index='token', columns='topic').fill_null(0)
Vs = V.select([
    pl.col([f'k{i}' for i in range(k)]).sum()
])
Vlen = len(V)
print(Vlen)
Vs
# Out:
# 25372
# shape: (1, 10)
# ┌───────┬───────┬───────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ k0    ┆ k1    ┆ k2    ┆ k3    ┆ ... ┆ k6    ┆ k7    ┆ k8    ┆ k9    │
# │ ---   ┆ ---   ┆ ---   ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ u32   ┆ u32   ┆ u32   ┆ u32   ┆     ┆ u32   ┆ u32   ┆ u32   ┆ u32   │
# ╞═══════╪═══════╪═══════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ 59818 ┆ 59347 ┆ 59464 ┆ 59559 ┆ ... ┆ 59005 ┆ 59328 ┆ 59508 ┆ 59694 │
# └───────┴───────┴───────┴───────┴─────┴───────┴───────┴───────┴───────┘

# %%
D = W.groupby(['doc_id', 'topic']).count().with_columns([
    pl.col('topic').apply(lambda x: f'k{x}')
]).pivot(values='count', index='doc_id', columns='topic').fill_null(0)
Ds = D.select([
    pl.col('doc_id'),
    pl.sum(pl.col([f'k{i}' for i in range(k)]))
]).with_columns([pl.lit(0).alias('index')]).pivot(values='sum', index="index", columns='doc_id').drop('index')
Ds
# Out:
# shape: (1, 19579)
# ┌─────────┬─────────┬─────────┬─────────┬─────┬─────────┬─────────┬─────────┬─────────┐
# │ id09068 ┆ id06978 ┆ id04229 ┆ id13790 ┆ ... ┆ id05111 ┆ id17846 ┆ id26673 ┆ id16673 │
# │ ---     ┆ ---     ┆ ---     ┆ ---     ┆     ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ u32     ┆ u32     ┆ u32     ┆ u32     ┆     ┆ u32     ┆ u32     ┆ u32     ┆ u32     │
# ╞═════════╪═════════╪═════════╪═════════╪═════╪═════════╪═════════╪═════════╪═════════╡
# │ 29      ┆ 27      ┆ 42      ┆ 49      ┆ ... ┆ 5       ┆ 4       ┆ 4       ┆ 5       │
# └─────────┴─────────┴─────────┴─────────┴─────┴─────────┴─────────┴─────────┴─────────┘

# %%
def calc_prob(row):
    p = []
    for i in range(k):
        cdk = D.filter(
            pl.col('doc_id') == row["doc_id"]
        )[f'k{int(i)}'][0]
        ckv = V.filter(
            pl.col('token') == row["token"]
        )[f'k{int(i)}'][0]
        cd = Ds[0, row["doc_id"][0]]
        ck = Vs[0, f'k{int(row["topic"][0])}']
        p.append((alpha + cdk)/(k*alpha + cd) * (beta + ckv)/(Vlen*beta + ck))
    p = np.array(p)
    p = p/p.sum()
    return p




for it in range(3):
    for i in range(len(W)):
        if i % 5000 == 0:
            print('iteration:', it, 'in, token:', i, 'of', len(W))
        row = W[i, :]
        V.filter(
            pl.col('token') == row["token"]
        )[f'k{int(row["topic"][0])}'][0] -= 1
        D.filter(
            pl.col('doc_id') == row["doc_id"]
        )[f'k{int(row["topic"][0])}'][0] -= 1
        Ds[0, row["doc_id"][0]] -= 1
        Vs[0, f'k{int(row["topic"][0])}'] -= 1
        p = calc_prob(row)
        new_topic = int(np.random.choice(np.arange(10),  p=[1/k]*k))
        W[i, "topic"] = new_topic
        V.filter(
            pl.col('token') == row["token"]
        )[f'k{int(new_topic)}'][0] += 1
        D.filter(
            pl.col('doc_id') == row["doc_id"]
        )[f'k{int(new_topic)}'][0] += 1
        Ds[0, row["doc_id"][0]] += 1
        Vs[0, f'k{int(new_topic)}'] += 1
    print('iteration comlete', it)
# Out:
# iteration: 0 in, token: 0 of 594922
# iteration: 0 in, token: 5000 of 594922
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[134], line 35
#      33 p = calc_prob(row)
#      34 new_topic = int(np.random.choice(np.arange(10),  p=[1/k]*k))
# ---> 35 W[i, "topic"] = new_topic
#      36 V.filter(
#      37     pl.col('token') == row["token"]
#      38 )[f'k{int(new_topic)}'][0] += 1
#      39 D.filter(
#      40     pl.col('doc_id') == row["doc_id"]
#      41 )[f'k{int(new_topic)}'][0] += 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\dataframe\frame.py:1686, in DataFrame.__setitem__(self, key, value)
#    1683     raise ValueError(f"column selection not understood: {col_selection}")
#    1685 # dispatch to __setitem__ of Series to do modification
# -> 1686 s[row_selection] = value
#    1688 # now find the location to place series
#    1689 # df[idx]
#    1690 if isinstance(col_selection, int):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\series\series.py:881, in Series.__setitem__(self, key, value)
#     874 def __setitem__(
#     875     self,
#     876     key: int | Series | np.ndarray[Any, Any] | Sequence[object] | tuple[object],
#     877     value: Any,
#     878 ) -> None:
#     879     # do the single idx as first branch as those are likely in a tight loop
#     880     if isinstance(key, int) and not isinstance(key, bool):
# --> 881         self.set_at_idx(key, value)
#     882         return None
#     883     elif isinstance(value, Sequence) and not isinstance(value, str):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\series\series.py:3168, in Series.set_at_idx(self, idx, value)
#    3166     # if we need to set more than a single value, we extend it
#    3167     if len(idx) > 0:
# -> 3168         value = value.extend_constant(value[0], len(idx) - 1)
#    3169 elif not isinstance(value, Series):
#    3170     value = Series("", value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\series\utils.py:98, in call_expr.<locals>.wrapper(self, *args, **kwargs)
#      96     expr = getattr(expr, namespace)
#      97 f = getattr(expr, func.__name__)
# ---> 98 return s.to_frame().select(f(*args, **kwargs)).to_series()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\dataframe\frame.py:5851, in DataFrame.select(self, exprs, *more_exprs, **named_exprs)
#    5733 def select(
#    5734     self,
#    5735     exprs: (
#    (...)
#    5744     **named_exprs: str | PolarsExprType | PythonLiteral | pli.Series | None,
#    5745 ) -> Self:
#    5746     """
#    5747     Select columns from this DataFrame.
#    5748
#    (...)
#    5846
#    5847     """
#    5848     return self._from_pydf(
#    5849         self.lazy()
#    5850         .select(exprs, *more_exprs, **named_exprs)
# -> 5851         .collect(no_optimization=True)
#    5852         ._df
#    5853     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\polars\internals\lazyframe\frame.py:1147, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, no_optimization, slice_pushdown, common_subplan_elimination, streaming)
#    1136     common_subplan_elimination = False
#    1138 ldf = self._ldf.optimization_toggle(
#    1139     type_coercion,
#    1140     predicate_pushdown,
#    (...)
#    1145     streaming,
#    1146 )
# -> 1147 return pli.wrap_df(ldf.collect())
#
# KeyboardInterrupt:

# %%
df = pl.DataFrame({
    'a': range(5),
    'b': range(5)
})
df[3, 'b'] = 99

print(df)

Ds[0, 'id09068'] = 29
Ds
# Out:
# shape: (5, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 0   ┆ 0   │
# │ 1   ┆ 1   │
# │ 2   ┆ 2   │
# │ 3   ┆ 99  │
# │ 4   ┆ 4   │
# └─────┴─────┘
# shape: (1, 19579)
# ┌─────────┬─────────┬─────────┬─────────┬─────┬─────────┬─────────┬─────────┬─────────┐
# │ id09068 ┆ id06978 ┆ id04229 ┆ id13790 ┆ ... ┆ id05111 ┆ id17846 ┆ id26673 ┆ id16673 │
# │ ---     ┆ ---     ┆ ---     ┆ ---     ┆     ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ u32     ┆ u32     ┆ u32     ┆ u32     ┆     ┆ u32     ┆ u32     ┆ u32     ┆ u32     │
# ╞═════════╪═════════╪═════════╪═════════╪═════╪═════════╪═════════╪═════════╪═════════╡
# │ 29      ┆ 27      ┆ 42      ┆ 49      ┆ ... ┆ 5       ┆ 4       ┆ 4       ┆ 5       │
# └─────────┴─────────┴─────────┴─────────┴─────┴─────────┴─────────┴─────────┴─────────┘
